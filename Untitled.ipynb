# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\rohit\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
data=pd.read_csv('recipes.csv')

# %%
dataset=data.copy()
columns=['RecipeId','Name','CookTime','PrepTime','TotalTime','RecipeIngredientParts','Calories','FatContent','SaturatedFatContent','CholesterolContent','SodiumContent','CarbohydrateContent','FiberContent','SugarContent','ProteinContent','RecipeInstructions']
dataset=dataset[columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 522517 entries, 0 to 522516
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   RecipeId               522517 non-null  int64
#  1   Name                   522517 non-null  object
#  2   CookTime               439972 non-null  object
#  3   PrepTime               522517 non-null  object
#  4   TotalTime              522517 non-null  object
#  5   RecipeIngredientParts  522517 non-null  object
#  6   Calories               522517 non-null  float64
#  7   FatContent             522517 non-null  float64
#  8   SaturatedFatContent    522517 non-null  float64
#  9   CholesterolContent     522517 non-null  float64
#  10  SodiumContent          522517 non-null  float64
#  11  CarbohydrateContent    522517 non-null  float64
#  12  FiberContent           522517 non-null  float64
#  13  SugarContent           522517 non-null  float64
# ...

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(dataset.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Values in the Dataset')
plt.show()

# %%
dataset.to_csv('data.csv', index=False)

# %%
dataset.duplicated().sum()
# Out:
# 0

# %%
dataset1=data.copy()
columns=['Name','CookTime','PrepTime','TotalTime','RecipeIngredientParts','Calories','FatContent','SaturatedFatContent','CholesterolContent','SodiumContent','CarbohydrateContent','FiberContent','SugarContent','ProteinContent','RecipeInstructions']
dataset1=dataset1[columns]

# %%
dataset1.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 522512    False
# 522513    False
# 522514    False
# 522515    False
# 522516    False
# Length: 522517, dtype: bool

# %%
import pandas as pd

df = pd.DataFrame(dataset1)

# Check if any value in each column is boolean
bool_columns = df.columns[df.isin([True, False]).any()]

# Display columns with boolean values
print("Columns with boolean values:", bool_columns)
# Out:
# Columns with boolean values: Index(['Calories', 'FatContent', 'SaturatedFatContent', 'CholesterolContent',
#        'SodiumContent', 'CarbohydrateContent', 'FiberContent', 'SugarContent',
#        'ProteinContent'],
#       dtype='object')

# %%
duplicate_rows = dataset1[dataset1.duplicated()]

# %%
duplicate_rows
# Out:
#                                         Name CookTime PrepTime TotalTime  \
# 74607          Sausage, Pepper and Egg Heros    PT12M    PT15M     PT27M
# 82039                     Potato Chip Salmon     PT9M    PT10M     PT19M
# 120958            Hot and Sweet Baby Carrots     PT8M     PT5M     PT13M
# 156463  Mushroom, Bacon, and Potato Frittata    PT15M    PT20M     PT35M
# 157972        Roasted Garlic Macadamia Sauce     PT1H    PT15M   PT1H15M
# ...                                      ...      ...      ...       ...
# 521790                 Greek Meatball Kabobs    PT15M    PT35M     PT50M
# 521806                Moo Shu Pork Tortillas    PT10M    PT15M     PT25M
# 522037                 Hubby's Ham Casserole    PT30M    PT15M     PT45M
# 522039           Butter Pecan Banana Muffins    PT18M    PT10M     PT28M
# 522124               Three-Alarm Sloppy Joes    PT10M     PT2M     PT12M
#
#                                     RecipeIngredientParts  Calories  \
# ...

# %%
duplicated_columns1 = dataset1.T.duplicated()

# %%
duplicated_columns1
